# %%
import pandas as pd

# %%
df1 = pd.read_csv('olympic_old.csv')

# %%
df1.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
df1.Country=='GRE'
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 31160    False
# 31161    False
# 31162    False
# 31163    False
# 31164    False
# Name: Country, Length: 31165, dtype: bool

# %%
df1[df1.Country=='GRE']
# Out:
#        Year     City      Sport Discipline                 Athlete Country  \
# 2      1896   Athens   Aquatics   Swimming       DRIVAS, Dimitrios     GRE
# 3      1896   Athens   Aquatics   Swimming      MALOKINIS, Ioannis     GRE
# 4      1896   Athens   Aquatics   Swimming      CHASAPIS, Spiridon     GRE
# 5      1896   Athens   Aquatics   Swimming   CHOROPHAS, Efstathios     GRE
# 7      1896   Athens   Aquatics   Swimming        ANDREOU, Joannis     GRE
# ...     ...      ...        ...        ...                     ...     ...
# 28839  2008  Beijing    Sailing    Sailing     PAPADOPOULOU, Sofia     GRE
# 28975  2008  Beijing  Taekwondo  Taekwondo  NIKOLAIDIS, Alexandros     GRE
# 30629  2012   London       Judo       Judo          ILIADIS, Ilias     GRE
# 30753  2012   London     Rowing     Rowing  GIAZITZIDOU, Christina     GRE
# 30754  2012   London     Rowing     Rowing      TSIAVOU, Alexandra     GRE
#
#       Gender                       Event   Medal
# ...

# %%
(df1.Gender=='Women') & (df1.Medal=='Gold')  #it gives both T and F values
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31160    False
# 31161    False
# 31162    False
# 31163    False
# 31164    False
# Length: 31165, dtype: bool

# %%
df1[(df1.Gender=='Women') & (df1.Medal=='Gold')]   #it only gives the True values
# Out:
#        Year      City          Sport           Discipline  \
# 417    1900     Paris           Golf                 Golf
# 641    1900     Paris         Tennis               Tennis
# 649    1900     Paris         Tennis               Tennis
# 710    1904  St Louis        Archery              Archery
# 713    1904  St Louis        Archery              Archery
# ...     ...       ...            ...                  ...
# 31081  2012    London  Weightlifting        Weightlifting
# 31097  2012    London      Wrestling  Wrestling Freestyle
# 31105  2012    London      Wrestling  Wrestling Freestyle
# 31113  2012    London      Wrestling  Wrestling Freestyle
# 31121  2012    London      Wrestling  Wrestling Freestyle
#
#                      Athlete Country Gender  \
# 417    ABBOTT, Margaret Ives     USA  Women
# 641        COOPER, Charlotte     GBR  Women
# 649        COOPER, Charlotte     GBR  Women
# 710    HOWELL, Matilda Scott     USA  Women
# ...

# %%
df1[(df1.Gender=='Men') & (df1.Medal=='Gold')]   #it only gives the True values
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %% [markdown]
# ### String Handling

# %%
df1.Athlete.str.contains('HAJOS')
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 31160    False
# 31161    False
# 31162    False
# 31163    False
# 31164    False
# Name: Athlete, Length: 31165, dtype: bool

# %%
df1[df1.Athlete.str.contains('HAJOS')]
# Out:
#    Year    City     Sport Discipline        Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming  HAJOS, Alfred     HUN    Men
# 6  1896  Athens  Aquatics   Swimming  HAJOS, Alfred     HUN    Men
#
#              Event Medal
# 0   100M Freestyle  Gold
# 6  1200M Freestyle  Gold

# %%
df1[df1.Athlete.str.startswith('HAJOS')]
# Out:
#    Year    City     Sport Discipline        Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming  HAJOS, Alfred     HUN    Men
# 6  1896  Athens  Aquatics   Swimming  HAJOS, Alfred     HUN    Men
#
#              Event Medal
# 0   100M Freestyle  Gold
# 6  1200M Freestyle  Gold

# %%
df1[df1.Athlete.str.startswith('HA')]  #returns all athlete names whose last name starts with HA
# Out:
#        Year    City       Sport           Discipline               Athlete  \
# 0      1896  Athens    Aquatics             Swimming         HAJOS, Alfred
# 6      1896  Athens    Aquatics             Swimming         HAJOS, Alfred
# 151    1900   Paris    Aquatics             Swimming        HALMAY, Zoltan
# 159    1900   Paris    Aquatics             Swimming        HALMAY, Zoltan
# 169    1900   Paris    Aquatics             Swimming           HAINLE, Max
# ...     ...     ...         ...                  ...                   ...
# 30866  2012  London    Shooting             Shooting      HANCOCK, Vincent
# 30920  2012  London   Taekwondo            Taekwondo      HARNOIS, Marlene
# 31027  2012  London  Volleyball           Volleyball  HANEEF-PARK, Tayyiba
# 31028  2012  London  Volleyball           Volleyball     HARMOTTO, Christa
# 31127  2012  London   Wrestling  Wrestling Freestyle          HATOS, Gabor
#
#       Country Gender               Event   Medal
# ...

# %%
df1.Medal == 'Gold'
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 31160    False
# 31161     True
# 31162    False
# 31163    False
# 31164    False
# Name: Medal, Length: 31165, dtype: bool

# %%
df1[df1.Medal == 'Gold']
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
df1[df1.Medal == 'Gold'].Medal.value_counts()
# Out:
# Gold    10486
# Name: Medal, dtype: int64

# %%
df1[df1.Medal == 'Gold'].Country.value_counts()
# Out:
# USA    2235
# URS     838
# GBR     546
# ITA     476
# GER     452
#        ...
# MOZ       1
# ISR       1
# RU1       1
# SYR       1
# ARM       1
# Name: Country, Length: 99, dtype: int64

# %%
df1[df1.Medal == 'Gold'].Country.value_counts()[:3]
# Out:
# USA    2235
# URS     838
# GBR     546
# Name: Country, dtype: int64

# %%
df1[df1.Medal == 'Gold'].Country.value_counts()[:0]
# Out:
# Series([], Name: Country, dtype: int64)

# %%
df1[df1.Medal == 'Gold'].Country.value_counts().index
# Out:
# Index(['USA', 'URS', 'GBR', 'ITA', 'GER', 'HUN', 'FRA', 'SWE', 'GDR', 'AUS',
#        'CHN', 'RUS', 'NED', 'JPN', 'NOR', 'CUB', 'KOR', 'ROU', 'CAN', 'DEN',
#        'FRG', 'YUG', 'IND', 'FIN', 'POL', 'ESP', 'EUN', 'BEL', 'NZL', 'TCH',
#        'SUI', 'BRA', 'ARG', 'EUA', 'BUL', 'CRO', 'URU', 'PAK', 'UKR', 'TUR',
#        'GRE', 'MEX', 'JAM', 'RSA', 'KEN', 'ZZX', 'ETH', 'AUT', 'ANZ', 'CMR',
#        'NGR', 'ZIM', 'BLR', 'IRI', 'PRK', 'CZE', 'BAH', 'KAZ', 'SVK', 'INA',
#        'EST', 'IRL', 'THA', 'EGY', 'MAR', 'LTU', 'GEO', 'AZE', 'SLO', 'UZB',
#        'ALG', 'TUN', 'POR', 'TPE', 'DOM', 'LAT', 'CHI', 'VEN', 'MGL', 'UGA',
#        'COL', 'UAE', 'TRI', 'PER', 'ECU', 'CRC', 'GRN', 'PAN', 'TTO', 'BDI',
#        'SRB', 'HKG', 'LUX', 'SUR', 'MOZ', 'ISR', 'RU1', 'SYR', 'ARM'],
#       dtype='object')

# %%
df1[df1.Medal == 'Gold'].Country.value_counts().index[0:3]
# Out:
# Index(['USA', 'URS', 'GBR'], dtype='object')

# %%
c1,c2,c3 = df1[df1.Medal == 'Gold'].Country.value_counts().index[0:3]
print("{x} > {y} > {z}".format(x=c1, y=c2, z=c3))
# Out:
# USA > URS > GBR

# %%
df1[(df1.Gender=="Men") & (df1.Medal=="Gold") & (df1.Event=='100M Freestyle')]
# Out:
#        Year                   City     Sport Discipline  \
# 0      1896                 Athens  Aquatics   Swimming
# 674    1904               St Louis  Aquatics   Swimming
# 1144   1908                 London  Aquatics   Swimming
# 1953   1912              Stockholm  Aquatics   Swimming
# 2841   1920                Antwerp  Aquatics   Swimming
# 4142   1924                  Paris  Aquatics   Swimming
# 5023   1928              Amsterdam  Aquatics   Swimming
# 5733   1932            Los Angeles  Aquatics   Swimming
# 6348   1936                 Berlin  Aquatics   Swimming
# 7223   1948                 London  Aquatics   Swimming
# 8037   1952               Helsinki  Aquatics   Swimming
# 8929   1956  Melbourne / Stockholm  Aquatics   Swimming
# 9814   1960                   Rome  Aquatics   Swimming
# 10693  1964                  Tokyo  Aquatics   Swimming
# 11715  1968                 Mexico  Aquatics   Swimming
# 12746  1972                 Munich  Aquatics   Swimming
# ...

# %%
df1.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
df1.Gender.value_counts()
# Out:
# Men      22746
# Women     8419
# Name: Gender, dtype: int64

# %% [markdown]
# ### Basic Plotting

# %%
df1.Gender.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df1.Gender.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
width = height= 9
df1.Gender.value_counts().plot(kind='pie', figsize=(width,height))
# Out:
# <AxesSubplot:ylabel='Gender'>

# %%
df1
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# # Indexing

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=31165, step=1)

# %%
type(df1.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df1.index[0] = 100 #index is immutable so error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-ba0ef3e33b26> in <module>
# ----> 1 df1.index[0] = 100
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in __setitem__(self, key, value)
#    4275     @final
#    4276     def __setitem__(self, key, value):
# -> 4277         raise TypeError("Index does not support mutable operations")
#    4278
#    4279     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations

# %%
df1.set_index('Athlete') #change is not permanent
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
df1.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
df1.set_index('Athlete', inplace=True) #setting inplace=true makes changes permanent

# %%
df1.head()
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
df1.reset_index(inplace=True)  #resets to original value that inplace one

# %%
df1.head()
# Out:
#               Athlete  Year    City     Sport Discipline Country Gender  \
# 0       HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
# 1    HERSCHMANN, Otto  1896  Athens  Aquatics   Swimming     AUT    Men
# 2   DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
# 3  MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# 4  CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
df1.sort_index()
# Out:
#                           index  Year      City       Sport   Discipline  \
# Athlete
# AABYE, Edgar                651  1900     Paris  Tug of War   Tug of War
# AALTONEN, Arvo Ossian      2849  1920   Antwerp    Aquatics     Swimming
# AALTONEN, Arvo Ossian      2852  1920   Antwerp    Aquatics     Swimming
# AALTONEN, Paavo Johannes   7773  1948    London  Gymnastics  Artistic G.
# AALTONEN, Paavo Johannes   8563  1952  Helsinki  Gymnastics  Artistic G.
# ...                         ...   ...       ...         ...          ...
# ÖSTMO, Ole                  596  1900     Paris    Shooting     Shooting
# ÖSTMO, Ole                  608  1900     Paris    Shooting     Shooting
# ÖSTMO, Ole                  621  1900     Paris    Shooting     Shooting
# ÖSTMO, Ole                  603  1900     Paris    Shooting     Shooting
# ÖSTRAND, Per-Olof          8051  1952  Helsinki    Aquatics     Swimming
#
#                          Country Gender                          Event   Medal
# ...

# %%
df1.sort_index(inplace = True)

# %%
df1.loc['AABYE, Edgar']
# Out:
# index                651
# Year                1900
# City               Paris
# Sport         Tug of War
# Discipline    Tug of War
# Country              ZZX
# Gender               Men
# Event         Tug Of War
# Medal               Gold
# Name: AABYE, Edgar, dtype: object

# %%
df1.loc['ÖSTMO, Ole']
# Out:
#             index  Year   City     Sport Discipline Country Gender  \
# Athlete
# ÖSTMO, Ole    596  1900  Paris  Shooting   Shooting     NOR    Men
# ÖSTMO, Ole    608  1900  Paris  Shooting   Shooting     NOR    Men
# ÖSTMO, Ole    621  1900  Paris  Shooting   Shooting     NOR    Men
# ÖSTMO, Ole    603  1900  Paris  Shooting   Shooting     NOR    Men
#
#                                     Event   Medal
# Athlete
# ÖSTMO, Ole  Army Rifle, 300M, 3 Positions  Bronze
# ÖSTMO, Ole     Army Rifle, 300M, Standing  Silver
# ÖSTMO, Ole               Free Rifle, Team  Silver
# ÖSTMO, Ole        Army Rifle, 300M, Prone  Bronze

# %%
df1.iloc[4]
# Out:
# Athlete               CHASAPIS, Spiridon
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Silver
# Name: 4, dtype: object

# %%
df1.iloc[[0,4,10]]
# Out:
#                Athlete  Year    City     Sport Discipline Country Gender  \
# 0        HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
# 4   CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
# 10   PEPANOS, Antonios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                          Event   Medal
# 0               100M Freestyle    Gold
# 4   100M Freestyle For Sailors  Silver
# 10              400M Freestyle  Silver

# %%
df1.iloc[0:10]
# Out:
#                  Athlete  Year    City     Sport Discipline Country Gender  \
# 0          HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
# 1       HERSCHMANN, Otto  1896  Athens  Aquatics   Swimming     AUT    Men
# 2      DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
# 3     MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# 4     CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
# 5  CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# 6          HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN    Men
# 7       ANDREOU, Joannis  1896  Athens  Aquatics   Swimming     GRE    Men
# 8  CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# 9          NEUMANN, Paul  1896  Athens  Aquatics   Swimming     AUT    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# ...

# %%
df1.reset_index(inplace=True)

# %%
df1.head()
# Out:
#    index             Athlete  Year    City     Sport Discipline Country  \
# 0      0       HAJOS, Alfred  1896  Athens  Aquatics   Swimming     HUN
# 1      1    HERSCHMANN, Otto  1896  Athens  Aquatics   Swimming     AUT
# 2      2   DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE
# 3      3  MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE
# 4      4  CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE
#
#   Gender                       Event   Medal
# 0    Men              100M Freestyle    Gold
# 1    Men              100M Freestyle  Silver
# 2    Men  100M Freestyle For Sailors  Bronze
# 3    Men  100M Freestyle For Sailors    Gold
# 4    Men  100M Freestyle For Sailors  Silver

# %%
df1.loc[2]
# Out:
# index                                  2
# Athlete                DRIVAS, Dimitrios
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: 2, dtype: object

# %%
df1.set_index('Athlete', inplace=True)  #reset so that iloc works bcz without this iloc will return error bcz of string values
df1.head()
# Out:
#                     index  Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred           0  1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto        1  1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios       2  1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis      3  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon      4  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
df1.iloc[4]
# Out:
# index                                  4
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Silver
# Name: CHASAPIS, Spiridon, dtype: object

# %%
df1.iloc[[1,2,4]]
# Out:
#                     index  Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto        1  1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios       2  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon      4  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
df1[df1.Country=='IND']
# Out:
#                       index  Year       City      Sport           Discipline  \
# Athlete
# PRITCHARD, Norman       241  1900      Paris  Athletics            Athletics
# PRITCHARD, Norman       244  1900      Paris  Athletics            Athletics
# ALLEN, Richard James   5512  1928  Amsterdam     Hockey               Hockey
# CHAND, Dyan            5513  1928  Amsterdam     Hockey               Hockey
# GATELEY, Maurice A.    5514  1928  Amsterdam     Hockey               Hockey
# ...                     ...   ...        ...        ...                  ...
# KOM, Mary             29879  2012     London     Boxing               Boxing
# NARANG, Gagan         30841  2012     London   Shooting             Shooting
# KUMAR, Vijay          30849  2012     London   Shooting             Shooting
# DUTT, Yogeshwar       31111  2012     London  Wrestling  Wrestling Freestyle
# KUMAR, Sushil         31118  2012     London  Wrestling  Wrestling Freestyle
#
# ...

# %%
df1.groupby('Year')  #to obtain table in certain groups

# %%
list(df1.groupby('Year')) #returns of list tuples
# Out:
# [(1896,
#                             index  Year    City          Sport       Discipline  \
#   Athlete
#   HAJOS, Alfred                 0  1896  Athens       Aquatics         Swimming
#   HERSCHMANN, Otto              1  1896  Athens       Aquatics         Swimming
#   DRIVAS, Dimitrios             2  1896  Athens       Aquatics         Swimming
#   MALOKINIS, Ioannis            3  1896  Athens       Aquatics         Swimming
#   CHASAPIS, Spiridon            4  1896  Athens       Aquatics         Swimming
#   ...                         ...   ...     ...            ...              ...
#   JENSEN, Viggo               146  1896  Athens  Weightlifting    Weightlifting
#   ELLIOTT, Launceston         147  1896  Athens  Weightlifting    Weightlifting
#   CHRISTOPOULOS, Stephanos    148  1896  Athens      Wrestling  Wrestling Gre-R
#   SCHUMANN, Carl              149  1896  Athens      Wrestling  Wrestling Gre-R
# ...

# %%
dfgb = list(df1.groupby('Year'))

# %%
dfgb[0]
# Out:
# (1896,
#                            index  Year    City          Sport       Discipline  \
#  Athlete
#  HAJOS, Alfred                 0  1896  Athens       Aquatics         Swimming
#  HERSCHMANN, Otto              1  1896  Athens       Aquatics         Swimming
#  DRIVAS, Dimitrios             2  1896  Athens       Aquatics         Swimming
#  MALOKINIS, Ioannis            3  1896  Athens       Aquatics         Swimming
#  CHASAPIS, Spiridon            4  1896  Athens       Aquatics         Swimming
#  ...                         ...   ...     ...            ...              ...
#  JENSEN, Viggo               146  1896  Athens  Weightlifting    Weightlifting
#  ELLIOTT, Launceston         147  1896  Athens  Weightlifting    Weightlifting
#  CHRISTOPOULOS, Stephanos    148  1896  Athens      Wrestling  Wrestling Gre-R
#  SCHUMANN, Carl              149  1896  Athens      Wrestling  Wrestling Gre-R
#  TSITAS, Georgios            150  1896  Athens      Wrestling  Wrestling Gre-R
#
# ...

# %%
dfgb[0][1] #dataframe of year 1896
# Out:
#                           index  Year    City          Sport       Discipline  \
# Athlete
# HAJOS, Alfred                 0  1896  Athens       Aquatics         Swimming
# HERSCHMANN, Otto              1  1896  Athens       Aquatics         Swimming
# DRIVAS, Dimitrios             2  1896  Athens       Aquatics         Swimming
# MALOKINIS, Ioannis            3  1896  Athens       Aquatics         Swimming
# CHASAPIS, Spiridon            4  1896  Athens       Aquatics         Swimming
# ...                         ...   ...     ...            ...              ...
# JENSEN, Viggo               146  1896  Athens  Weightlifting    Weightlifting
# ELLIOTT, Launceston         147  1896  Athens  Weightlifting    Weightlifting
# CHRISTOPOULOS, Stephanos    148  1896  Athens      Wrestling  Wrestling Gre-R
# SCHUMANN, Carl              149  1896  Athens      Wrestling  Wrestling Gre-R
# TSITAS, Georgios            150  1896  Athens      Wrestling  Wrestling Gre-R
#
# ...

# %%
for year, group in dfgb:
    print(year)
    print(group)
# Out:
# 1896
#                           index  Year    City          Sport       Discipline  \
# Athlete
# HAJOS, Alfred                 0  1896  Athens       Aquatics         Swimming
# HERSCHMANN, Otto              1  1896  Athens       Aquatics         Swimming
# DRIVAS, Dimitrios             2  1896  Athens       Aquatics         Swimming
# MALOKINIS, Ioannis            3  1896  Athens       Aquatics         Swimming
# CHASAPIS, Spiridon            4  1896  Athens       Aquatics         Swimming
# ...                         ...   ...     ...            ...              ...
# JENSEN, Viggo               146  1896  Athens  Weightlifting    Weightlifting
# ELLIOTT, Launceston         147  1896  Athens  Weightlifting    Weightlifting
# CHRISTOPOULOS, Stephanos    148  1896  Athens      Wrestling  Wrestling Gre-R
# SCHUMANN, Carl              149  1896  Athens      Wrestling  Wrestling Gre-R
# TSITAS, Georgios            150  1896  Athens      Wrestling  Wrestling Gre-R
#
# ...

# %%
for year, group in dfgb:
    print(group)
# Out:
#                           index  Year    City          Sport       Discipline  \
# Athlete
# HAJOS, Alfred                 0  1896  Athens       Aquatics         Swimming
# HERSCHMANN, Otto              1  1896  Athens       Aquatics         Swimming
# DRIVAS, Dimitrios             2  1896  Athens       Aquatics         Swimming
# MALOKINIS, Ioannis            3  1896  Athens       Aquatics         Swimming
# CHASAPIS, Spiridon            4  1896  Athens       Aquatics         Swimming
# ...                         ...   ...     ...            ...              ...
# JENSEN, Viggo               146  1896  Athens  Weightlifting    Weightlifting
# ELLIOTT, Launceston         147  1896  Athens  Weightlifting    Weightlifting
# CHRISTOPOULOS, Stephanos    148  1896  Athens      Wrestling  Wrestling Gre-R
# SCHUMANN, Carl              149  1896  Athens      Wrestling  Wrestling Gre-R
# TSITAS, Georgios            150  1896  Athens      Wrestling  Wrestling Gre-R
#
# ...

# %%
for year, group in dfgb:
    print(group.iloc[:5], [0, 1, 2])
# Out:
#                     index  Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred           0  1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto        1  1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios       2  1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis      3  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon      4  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver   [0, 1, 2]
#                      index  Year   City     Sport Discipline Country Gender  \
# Athlete
# ...
